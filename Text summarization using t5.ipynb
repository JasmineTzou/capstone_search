# %%
! pip install spark-nlp-display
# Install PySpark and Spark NLP
! pip install -q pyspark==3.1.2 spark-nlp==4.2.8
# Out:
# Requirement already satisfied: spark-nlp-display in /usr/local/lib/python3.10/dist-packages (5.0)
# Requirement already satisfied: spark-nlp in /usr/local/lib/python3.10/dist-packages (from spark-nlp-display) (4.2.8)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from spark-nlp-display) (7.34.0)
# Requirement already satisfied: svgwrite==1.4 in /usr/local/lib/python3.10/dist-packages (from spark-nlp-display) (1.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from spark-nlp-display) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from spark-nlp-display) (1.23.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->spark-nlp-display) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->spark-nlp-display) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->spark-nlp-display) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->spark-nlp-display) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->spark-nlp-display) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->spark-nlp-display) (3.0.41)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->spark-nlp-display) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->spark-nlp-display) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->spark-nlp-display) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->spark-nlp-display) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->spark-nlp-display) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->spark-nlp-display) (2023.3.post1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->spark-nlp-display) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->spark-nlp-display) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->spark-nlp-display) (0.2.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->spark-nlp-display) (1.16.0)

# %%
import pandas as pd
import numpy as np
import json

from pyspark.ml import Pipeline
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

import sparknlp
from sparknlp.annotator import *
from sparknlp.base import *
from sparknlp.pretrained import PretrainedPipeline
from pyspark.sql.types import StringType, IntegerType

# %%
spark = sparknlp.start()
print ("Spark NLP Version :", sparknlp.version())
spark
# Out:
# Spark NLP Version : 4.2.8
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://f0f8930f7cbd:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = spark.read.json('/content/drive/MyDrive/Capstone-esya.ai/DATA/summarized_df1000_1.json')

# %%
df.show(10)
# Out:
# +--------------------+-----------+--------------------+--------------------+--------------------+--------------------+----------+
# |         article_url|    section|         summary_gpt|                text|               title|             website|word_count|
# +--------------------+-----------+--------------------+--------------------+--------------------+--------------------+----------+
# |https://www.dhaka...|      world| The government a...|An Indian court j...|Self-styled India...|www.dhakatribune.com|       404|
# |https://www.dhaka...|latest-news| The St Louis Cou...|US police said ea...|Police arrest 31 ...|www.dhakatribune.com|       571|
# |http://www.catchn...|       NEWS| The next hearing...|Here's a trivia q...|Shady deal: how a...|   www.catchnews.com|       840|
# |https://www.dhaka...|      world|                    |An Australian tra...|Australian blogge...|www.dhakatribune.com|       742|
# |https://www.dhaka...|      world|                    |Ten people were k...|Landslides kill 1...|www.dhakatribune.com|       121|
# |https://www.cbsne...|       U.S.| "I think it's a ...|   The Digital Re...|How the revolutio...|     www.cbsnews.com|       435|
# |https://www.dhaka...|      world| Coulibaly's vide...|Tens of thousands...|Unity and defianc...|www.dhakatribune.com|       724|
# |https://www.cbsne...|   Politics|
#
# Donald Trump's ...| He may be limite...|​Donald Trump ins...|     www.cbsnews.com|       374|
# |http://www.catchn...|       NEWS|                    |Defence Minister ...|Article 370 was a...|   www.catchnews.com|       323|
# |https://www.cbsne...|      World|  He's been by he...|Queen Elizabeth I...|Queen opens Parli...|     www.cbsnews.com|       309|
# +--------------------+-----------+--------------------+--------------------+--------------------+--------------------+----------+
# only showing top 10 rows

# %%
import pyspark.sql.functions as F
from pyspark.sql.functions import regexp_replace
#df = df.filter(F.regexp_extract(df.text, r"\b[a-zA-Z]+\b", 0) != "")
#df= df.select('article_url','hashtag','section','text','title','website')
#df.count()

# %%
document_assembler = DocumentAssembler()\
                    .setInputCol("text")\
                    .setOutputCol("documents")

t5 = T5Transformer() \
    .pretrained("t5_small", 'en') \
    .setTask("summarize:")\
    .setMaxOutputLength(100)\
    .setInputCols(["documents"]) \
    .setOutputCol("summaries")

summarizer_pp = Pipeline(stages=[
    document_assembler, t5
])
# Out:
# t5_small download started this may take some time.
# Approximate size to download 141.1 MB
# [OK!]

# %%
#df=df.select("text")
#df = spark.createDataFrame(df, StringType()).toDF("text")
result = summarizer_pp.fit(df).transform(df)

# %%
result.show(10)
# Out:
# +--------------------+-----------+--------------------+--------------------+--------------------+--------------------+----------+--------------------+--------------------+
# |         article_url|    section|         summary_gpt|                text|               title|             website|word_count|           documents|           summaries|
# +--------------------+-----------+--------------------+--------------------+--------------------+--------------------+----------+--------------------+--------------------+
# |https://www.dhaka...|      world| The government a...|An Indian court j...|Self-styled India...|www.dhakatribune.com|       404|[{document, 0, 24...|[{document, 0, 20...|
# |https://www.dhaka...|latest-news| The St Louis Cou...|US police said ea...|Police arrest 31 ...|www.dhakatribune.com|       571|[{document, 0, 34...|[{document, 0, 17...|
# |http://www.catchn...|       NEWS| The next hearing...|Here's a trivia q...|Shady deal: how a...|   www.catchnews.com|       840|[{document, 0, 50...|[{document, 0, 20...|
# |https://www.dhaka...|      world|                    |An Australian tra...|Australian blogge...|www.dhakatribune.com|       742|[{document, 0, 46...|[{document, 0, 25...|
# |https://www.dhaka...|      world|                    |Ten people were k...|Landslides kill 1...|www.dhakatribune.com|       121|[{document, 0, 78...|[{document, 0, 20...|
# |https://www.cbsne...|       U.S.| "I think it's a ...|   The Digital Re...|How the revolutio...|     www.cbsnews.com|       435|[{document, 0, 23...|[{document, 0, 16...|
# |https://www.dhaka...|      world| Coulibaly's vide...|Tens of thousands...|Unity and defianc...|www.dhakatribune.com|       724|[{document, 0, 43...|[{document, 0, 19...|
# |https://www.cbsne...|   Politics|
#
# Donald Trump's ...| He may be limite...|​Donald Trump ins...|     www.cbsnews.com|       374|[{document, 0, 21...|[{document, 0, 23...|
# |http://www.catchn...|       NEWS|                    |Defence Minister ...|Article 370 was a...|   www.catchnews.com|       323|[{document, 0, 18...|[{document, 0, 26...|
# |https://www.cbsne...|      World|  He's been by he...|Queen Elizabeth I...|Queen opens Parli...|     www.cbsnews.com|       309|[{document, 0, 17...|[{document, 0, 24...|
# +--------------------+-----------+--------------------+--------------------+--------------------+--------------------+----------+--------------------+--------------------+
# only showing top 10 rows

# %%
#sum.schema[result].dataType
result.printSchema()
# Out:
# root
#  |-- article_url: string (nullable = true)
#  |-- section: string (nullable = true)
#  |-- summary_gpt: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- website: string (nullable = true)
#  |-- word_count: long (nullable = true)
#  |-- documents: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)
#  |-- summaries: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)

# %%
df1= result.select("article_url","section","summary_gpt", "title","website","text","summaries.result")

# %%
df1.show(10)
# Out:
# +--------------------+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |         article_url|    section|         summary_gpt|               title|             website|                text|              result|
# +--------------------+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |https://www.dhaka...|      world| The government a...|Self-styled India...|www.dhakatribune.com|An Indian court j...|[a judge jails a ...|
# |https://www.dhaka...|latest-news| The St Louis Cou...|Police arrest 31 ...|www.dhakatribune.com|US police said ea...|[police say 31 pe...|
# |http://www.catchn...|       NEWS| The next hearing...|Shady deal: how a...|   www.catchnews.com|Here's a trivia q...|[TERI's governing...|
# |https://www.dhaka...|      world|                    |Australian blogge...|www.dhakatribune.com|An Australian tra...|[australian coupl...|
# |https://www.dhaka...|      world|                    |Landslides kill 1...|www.dhakatribune.com|Ten people were k...|[landslides struc...|
# |https://www.cbsne...|       U.S.| "I think it's a ...|How the revolutio...|     www.cbsnews.com|   The Digital Re...|[the digital revo...|
# |https://www.dhaka...|      world| Coulibaly's vide...|Unity and defianc...|www.dhakatribune.com|Tens of thousands...|[a new shooting w...|
# |https://www.cbsne...|   Politics|
#
# Donald Trump's ...|​Donald Trump ins...|     www.cbsnews.com| He may be limite...|[he re-tweeted a ...|
# |http://www.catchn...|       NEWS|                    |Article 370 was a...|   www.catchnews.com|Defence Minister ...|[the defence mini...|
# |https://www.cbsne...|      World|  He's been by he...|Queen opens Parli...|     www.cbsnews.com|Queen Elizabeth I...|[queen Elizabeth ...|
# +--------------------+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 10 rows

# %%
df1_copy = df1.select('*')

# %%
# Use regexp_replace to remove square brackets from the specified column
result = result.withColumn("result", regexp_replace("result", r"\[|\]", ""))

# %%
df1_copy.write.json('/content/drive/MyDrive/Capstone-esya.ai/DATA/final_df1000.json')

# %% [markdown]
# Use ROUGE score to evaluate

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import FloatType

# %%
# Define a UDF for ROUGE calculation
def calculate_rouge(reference, candidate):
    reference = reference.split()
    candidate = candidate.split()
    score = sentence_bleu([reference], candidate)
    return score

calculate_rouge_udf = udf(calculate_rouge, FloatType())

# %%
df2 = df1.withColumn("rouge_score", calculate_rouge_udf(df1["summary"], df1["result"]))

# %%
df2.show(10,truncate=True)

# %%
#calcualte the average rouge score
df2.agg({'rouge_score': 'avg'}).show()

# %%
spark.stop()
